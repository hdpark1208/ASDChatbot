# %% [markdown]
# <a href="https://colab.research.google.com/github/hdpark1208/ASDChatbot/blob/main/Algorithm/PG/%EC%8B%A0%EA%B7%9C_%EC%95%84%EC%9D%B4%EB%94%94_%EC%B6%94%EC%B2%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 신규 아이디 추천

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 입력 출력 및 예제

# %% [markdown]
# * 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 출력

# %% [markdown]
# * 예제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 구상

# %% [markdown]
# -

# %% [markdown]
# ## 코드

# %%
def solution(new_id):
    answer = ''
    temp = ''
    temp_2 = ''
    cur_ch = ''

    new_id = new_id.lower() # 1단계

    for i in new_id: # 2단계
        if 'a' <= i <= 'z' or '0' <= i <= '9' or i == '-' or i == '_' or i == '.':
            temp += i

    for i in temp: # 3단계
        if i != '.':
            temp_2 += i
            cur_ch = i
        else:
            if cur_ch == '.':
                pass
            else:
                temp_2 += i
                cur_ch = i

    while True: # 4단계
        if temp_2 == '':
            break

        if temp_2[0] == '.':
            temp_2 = temp_2[1:]
        elif temp_2[-1] == '.':
            temp_2 = temp_2[:-1]
        else:
            break

    if temp_2 == '': # 5단계
        temp_2 = 'a'

    if len(temp_2) >= 16: # 6단계
        temp_2 = temp_2[:15]
        if temp_2[14] == '.':
            temp_2 = temp_2[:14]

    while len(temp_2) < 3: # 7단계
        if len(temp_2) <= 2:
            temp_2 += temp_2[-1]



    return temp_2

# %%
# GPT

def solution(new_id):
    # 1단계: 소문자 변환
    new_id = new_id.lower()

    # 2단계: 허용 문자만 남기기
    allowed = set("abcdefghijklmnopqrstuvwxyz0123456789-_.")
    new_id = ''.join(ch for ch in new_id if ch in allowed)

    # 3단계: 연속된 마침표 ".." => "."
    # 파이썬 replace 반복 사용: ".."가 없을 때까지 반복
    while ".." in new_id:
        new_id = new_id.replace("..", ".")

    # 4단계: 양 끝의 "." 제거
    new_id = new_id.strip(".")

    # 5단계: 빈 문자열이면 "a"
    if new_id == "":
        new_id = "a"

    # 6단계: 16자 이상이면 앞 15자 자르고 끝 "." 제거
    if len(new_id) >= 16:
        new_id = new_id[:15].rstrip(".")

    # 7단계: 길이가 3 미만이면 마지막 문자 반복
    while len(new_id) < 3:
        new_id += new_id[-1]

    return new_id

# %%
# new_id = "...!@BaT#*..y.abcdefghijklm"
# new_id = "z-+.^."
# new_id = "=.="
new_id = "abcdefghijklmn.p"

# %%
solution(new_id)
# Out:
# 'abcdefghijklmn'

# %%
solution(new_id)
# Out:
# '.bat.y.abcdefghijklm'

# %%
solution(new_id)
# Out:
# 'bat.y.abcdefghijklm'

# %%
solution(new_id)
# Out:
# 'bat.y.abcdefghi'

# %% [markdown]
# ### 메모
# -

# %% [markdown]
# *
